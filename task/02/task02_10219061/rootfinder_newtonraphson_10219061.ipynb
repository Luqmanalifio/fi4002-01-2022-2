# %%
import math

def f(x):
    y=3*x*x*x+8*x*x-23*x-28
    return y

x = [i * 0.03  for i in range(0, 100 + 1)]
y = [f(i) for i in x]

def df(x):
    y=9*x*x+16*x-23
    return y

# %%
xroot = []
yroot = []

x0 = 1
y0 = f(x0)

xroot.append(x0)
yroot.append(y0)

i = 1
eps = 1E-6
dx = 10
print("iter root         f(root)")
while dx > eps and i < 20:
    x0 = xroot[i-1]
    if i == 1:
        print(f"{i-1:04d}", f"{x0:.6E}", f"{f(x0):+.6E}")
    
    x1 = x0 - f(x0) / df(x0)
    
    xroot.append(x1)
    dx = abs(f(x1))
    
    print(f"{i:04d}", f"{x1:.6E}", f"{f(x1):+.6E}")
    i += 1
# Out:
# iter root         f(root)
# 0000 1.000000E+00 -4.000000E+01
# 0001 2.100000E+01 +3.080000E+04
# 0002 1.380710E+01 +9.075915E+03
# 0003 9.064344E+00 +2.655062E+03
# 0004 5.982404E+00 +7.630337E+02
# 0005 4.049797E+00 +2.093220E+02
# 0006 2.944639E+00 +5.023847E+01
# 0007 2.452839E+00 +7.987982E+00
# 0008 2.339362E+00 +3.828975E-01
# 0009 2.333350E+00 +1.049671E-03
# 0010 2.333333E+00 +7.965781E-09

# %%
print("root =", xroot[-1])
print("f(root) =", f(xroot[-1]))
# Out:
# root = 2.333333333459109
# f(root) = 7.965780923768762e-09

# %%
yroot = [f(i) for i in xroot]

# %%
import matplotlib.pyplot as plt
plt.grid()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.xlim(0, 3)
plt.ylim(-50, 50)
plt.plot(x, y, '-', xroot, yroot, 'r.', lw=2)
plt.show()

# %%
plt.grid()
plt.xlabel("iter")
plt.ylabel("f(x)")
plt.plot(yroot, 'r.-')
plt.show()

# %%
plt.grid()
plt.xlabel("iter")
plt.ylabel("x")
plt.plot(xroot, 'r.-')
plt.show()
