# %%
import math

def f(x):
    y=3*x*x*x+8*x*x-23*x-28
    return y

x = [i * 0.03  for i in range(-100, 100 + 1)]
y = [f(i) for i in x]

def g(x):
    d =(3*x*x*x+8*x*x-28)/23
    return d

# %%
xroot = []
yroot = []

x0 = 2.3
y0 = f(x0)
xroot.append(x0)
yroot.append(y0)

i = 1
eps = 1E-6
dx = 10
print("iter root         f(root)")
while dx > eps and i < 100:
    x0 = xroot[i-2]
    x1 = xroot[i-1]
    if i == 1:
        print(f"{i-1:04d}", f"{x1:.6E}", f"{f(x1):+.6E}")
    
    x1 = g(x0)
    
    xroot.append(x1)
    dx = abs(f(x1))
    
    print(f"{i:04d}", f"{x1:.6E}", f"{f(x1):+.6E}")
    i += 1
# Out:
# iter root         f(root)
# 0000 2.300000E+00 -2.079000E+00
# 0001 2.209609E+00 -7.397650E+00
# 0002 2.209609E+00 -7.397650E+00
# 0003 1.887972E+00 -2.271918E+01
# 0004 1.887972E+00 -2.271918E+01
# 0005 9.001813E-01 -4.003324E+01
# 0006 9.001813E-01 -4.003324E+01
# 0007 -8.403942E-01 -4.801449E+00
# 0008 -8.403942E-01 -4.801449E+00
# 0009 -1.049153E+00 +1.471815E+00
# 0010 -1.049153E+00 +1.471815E+00
# 0011 -9.851610E-01 -4.453818E-01
# 0012 -9.851610E-01 -4.453818E-01
# 0013 -1.004525E+00 +1.357406E-01
# 0014 -1.004525E+00 +1.357406E-01
# 0015 -9.986236E-01 -4.129350E-02
# 0016 -9.986236E-01 -4.129350E-02
# 0017 -1.000419E+00 +1.256930E-02
# 0018 -1.000419E+00 +1.256930E-02
# 0019 -9.998725E-01 -3.825279E-03
# 0020 -9.998725E-01 -3.825279E-03
# 0021 -1.000039E+00 +1.164230E-03
# 0022 -1.000039E+00 +1.164230E-03
# 0023 -9.999882E-01 -3.543295E-04
# 0024 -9.999882E-01 -3.543295E-04
# 0025 -1.000004E+00 +1.078395E-04
# 0026 -1.000004E+00 +1.078395E-04
# 0027 -9.999989E-01 -3.282072E-05
# 0028 -9.999989E-01 -3.282072E-05
# 0029 -1.000000E+00 +9.988915E-06
# 0030 -1.000000E+00 +9.988915E-06
# 0031 -9.999999E-01 -3.040104E-06
# 0032 -9.999999E-01 -3.040104E-06
# 0033 -1.000000E+00 +9.252492E-07

# %%
print("root =", xroot[-1])
print("f(root) =", f(xroot[-1]))
# Out:
# root = -1.0000000308416395
# f(root) = 9.252491821598596e-07

# %%
yroot = [f(i) for i in xroot]

# %%
import matplotlib.pyplot as plt
plt.grid()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.plot(x, y, '-', xroot, yroot, 'r.', lw=2)
plt.show()

# %%
plt.grid()
plt.xlabel("iter")
plt.ylabel("f(x)")
plt.plot(yroot, 'r.-')
plt.show()

# %%
plt.grid()
plt.xlabel("iter")
plt.ylabel("x")
plt.plot(xroot, 'r.-')
plt.show()
