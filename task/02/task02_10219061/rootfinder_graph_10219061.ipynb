# %%
import math
import matplotlib.pyplot as plt

def f(x):
    y=3*x*x*x+8*x*x-23*x-28
    return y

x = [i * math.pi / 100  for i in range(-200, 100 + 1)]
y = [f(i) for i in x]

ans = math.pi / 4  + math.pi / 6
xroot = [2.33333]
yroot = [0]

plt.grid()
plt.plot(x, y, xroot, yroot, 'r+', ms=10, lw=2)
plt.show()

# %%
xroot = [1.25]
yroot = [0]

plt.grid()
plt.xlim(2, 2.5)
plt.ylim(-0.25, 0.25)
plt.plot(x, y, xroot, yroot, 'r+', ms=10, lw=2)
plt.show()

# %%
xroot = [1.25]
yroot = [0]

plt.grid()
plt.xlim(2.3, 2.4)
plt.ylim(-0.25, 0.25)
plt.plot(x, y, xroot, yroot, 'r+', ms=10, lw=2)
plt.show()

# %%
xroot = [1.25]
yroot = [0]

plt.grid()
plt.xlim(2.32, 2.34)
plt.ylim(-0.25, 0.25)
plt.plot(x, y, xroot, yroot, 'r+', ms=10, lw=2)
plt.show()

# %%
xroot = [1.25]
yroot = [0]

plt.grid()
plt.xlim(2.3325, 2.3350)
plt.ylim(-0.25, 0.25)
plt.plot(x, y, xroot, yroot, 'r+', ms=10, lw=2)
plt.show()

# %%
xroot = [1.25]
yroot = [0]

plt.grid()
plt.xlim(2.3330, 2.3335)
plt.ylim(-0.05, 0.05)
plt.plot(x, y, xroot, yroot, 'r+', ms=10, lw=2)
plt.show()
