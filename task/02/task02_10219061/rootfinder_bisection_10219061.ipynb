# %%
import math

def f(x):
    y=3*x**3+8*x*x-23*x-28
    return y

x = [i * 0.03  for i in range(0, 100 + 1)]
y = [f(i) for i in x]

xroot = [2, 3]
yroot = [f(i) for i in xroot]

print("Root existance between", xroot[0], "and", xroot[1], ":", end=' ')
if yroot[0] * yroot[1] < 0:
    print(True)
else:
    print(False)
# Out:
# Root existance between 2 and 3 : True

# %%
x1 = xroot[0]
x2 = xroot[1]
x3 = 0.5 * (x1 + x2)
xroot.append(x3)

eps = 1E-6
dx = 10
i = 2
print("iter root         f(root)")
while dx > eps and i < 100:
    x1 = xroot[i-2]
    x2 = xroot[i-1]
    x3 = xroot[i]
    
    if i == 2:
        print(f"{i-2:04d}", f"{x1:.6E}", f"{f(x1):+.6E}")
        print(f"{i-1:04d}", f"{x2:.6E}", f"{f(x2):+.6E}")
        print(f"{i:04d}", f"{x3:.6E}", f"{f(x3):+.6E}")
   
    f13 = f(x1) * f(x3)
    f23 = f(x2) * f(x3)
     
    if f13 < 0:
        x4 = 0.5 * (x1 + x3)
        xroot[i-2] = x2
        xroot[i-1] = x1
    else:
        x4 = 0.5 * (x2 + x3)
    
    xroot.append(x4)
    dx = abs(f(x4))
    
    print(f"{i:04d}", f"{x4:.6E}", f"{f(x4):+.6E}")
    i += 1
# Out:
# iter root         f(root)
# 0000 2.000000E+00 -1.800000E+01
# 0001 3.000000E+00 +5.600000E+01
# 0002 2.500000E+00 +1.137500E+01
# 0002 2.250000E+00 -5.078125E+00
# 0003 2.375000E+00 +2.689453E+00
# 0004 2.312500E+00 -1.306885E+00
# 0005 2.343750E+00 +6.628723E-01
# 0006 2.328125E+00 -3.290749E-01
# 0007 2.335938E+00 +1.651273E-01
# 0008 2.332031E+00 -8.241612E-02
# 0009 2.333984E+00 +4.124493E-02
# 0010 2.333008E+00 -2.061325E-02
# 0011 2.333496E+00 +1.030893E-02
# 0012 2.333252E+00 -5.153888E-03
# 0013 2.333374E+00 +2.577088E-03
# 0014 2.333313E+00 -1.288508E-03
# 0015 2.333344E+00 +6.442630E-04
# 0016 2.333328E+00 -3.221292E-04
# 0017 2.333336E+00 +1.610652E-04
# 0018 2.333332E+00 -8.053245E-05
# 0019 2.333334E+00 +4.026626E-05
# 0020 2.333333E+00 -2.013312E-05
# 0021 2.333333E+00 +1.006656E-05
# 0022 2.333333E+00 -5.033281E-06
# 0023 2.333333E+00 +2.516641E-06
# 0024 2.333333E+00 -1.258320E-06
# 0025 2.333333E+00 +6.291602E-07

# %%
print("root =", xroot[-1])
print("f(root) =", f(xroot[-1]))
# Out:
# root = 2.333333343267441
# f(root) = 6.291601550856285e-07

# %%
yroot = [f(i) for i in xroot]

# %%
import matplotlib.pyplot as plt
plt.grid()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.plot(x, y, '-', xroot, yroot, 'r.', lw=2)
plt.show()

# %%
plt.grid()
plt.xlabel("iter")
plt.ylabel("f(x)")
plt.plot(yroot, 'r.-')
plt.show()

# %%
plt.grid()
plt.xlabel("iter")
plt.ylabel("x")
plt.plot(xroot, 'r.-')
plt.show()
